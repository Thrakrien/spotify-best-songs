# %%
import requests
import pandas as pd
import base64

# %%
client_id='1ea081e3c4d04a178150f5287edcfb7f'
client_secret='2788f6b0446a47fca4de16f370fc98b8'

# %%
client_creds = f'{client_id}:{client_secret}'
client_creds_b64 = base64.b64encode(client_creds.encode())
client_creds_b64
# Out:
# b'MWVhMDgxZTNjNGQwNGExNzgxNTBmNTI4N2VkY2ZiN2Y6Mjc4OGY2YjA0NDZhNDdmY2E0ZGUxNmYzNzBmYzk4Yjg='

# %%
token_url = 'https://accounts.spotify.com/api/token'
method='POST'

token_data = {
    'grant_type':'client_credentials'
}

token_headers = {
    "Authorization": f'Basic {client_creds_b64.decode()}'
}

token_headers
# Out:
# {'Authorization': 'Basic MWVhMDgxZTNjNGQwNGExNzgxNTBmNTI4N2VkY2ZiN2Y6Mjc4OGY2YjA0NDZhNDdmY2E0ZGUxNmYzNzBmYzk4Yjg='}

# %%
req = requests.post(token_url,data=token_data, headers=token_headers)
token_response_data = req.json()
req.status_code
# Out:
# 200

# %%
token_response_data = req.json()
access_token = token_response_data['access_token']
expires_in = token_response_data['expires_in']
token_type = token_response_data['token_type']
token_response_data
# Out:
# {'access_token': 'BQBkLLPy9Z34a9o_WKpSlI5xPixYPDaxoocOfJASByNSzQLNN_sctprRdyFx0p4OAoWNMQTJrOmnddJWPa_ZZ72yijZtciaNreTS3eETUQS30TVCdUg',
#  'token_type': 'Bearer',
#  'expires_in': 3600}

# %%
from urllib.parse import urlencode

# %%
headers = {
    'Authorization': f'Bearer {access_token}'
}
endpoint = 'https://api.spotify.com/v1/search'

data = urlencode({
    'q':'Neguin Cesar',
    'type':'track'
})
print(data)

lookup_url = f'{endpoint}?{data}'
print(lookup_url)

req = requests.get(lookup_url,headers=headers)
# Out:
# q=Neguin+Cesar&type=track
# https://api.spotify.com/v1/search?q=Neguin+Cesar&type=track

# %%
# Necessário tirar os países disponíveis

req.json()
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=Neguin+Cesar&type=track&offset=0&limit=20',
#   'items': [{'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/19JY4BpaJkAlSR4iDxB1MX'},
#        'href': 'https://api.spotify.com/v1/artists/19JY4BpaJkAlSR4iDxB1MX',
#        'id': '19JY4BpaJkAlSR4iDxB1MX',
#        'name': 'Cesar Mc',
#        'type': 'artist',
#        'uri': 'spotify:artist:19JY4BpaJkAlSR4iDxB1MX'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/09U6hmCerKcIJrixubiBjm'},
#        'href': 'https://api.spotify.com/v1/artists/09U6hmCerKcIJrixubiBjm',
#        'id': '09U6hmCerKcIJrixubiBjm',
#        'name': 'Pineapple StormTv',
#        'type': 'artist',
#        'uri': 'spotify:artist:09U6hmCerKcIJrixubiBjm'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/54gZAkXRSRi7kmetAOBlux'},
#      'href': 'https://api.spotify.com/v1/albums/54gZAkXRSRi7kmetAOBlux',
#      'id': '54gZAkXRSRi7kmetAOBlux',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273ab76513ca89b34aa9de736f3',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02ab76513ca89b34aa9de736f3',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851ab76513ca89b34aa9de736f3',
#        'width': 64}],
#      'name': 'Dai a Cesar o Que É de Cesar',
#      'release_date': '2021-09-08',
#      'release_date_precision': 'day',
#      'total_tracks': 7,
#      'type': 'album',
#      'uri': 'spotify:album:54gZAkXRSRi7kmetAOBlux'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/19JY4BpaJkAlSR4iDxB1MX'},
#       'href': 'https://api.spotify.com/v1/artists/19JY4BpaJkAlSR4iDxB1MX',
#       'id': '19JY4BpaJkAlSR4iDxB1MX',
#       'name': 'Cesar Mc',
#       'type': 'artist',
#       'uri': 'spotify:artist:19JY4BpaJkAlSR4iDxB1MX'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/09U6hmCerKcIJrixubiBjm'},
#       'href': 'https://api.spotify.com/v1/artists/09U6hmCerKcIJrixubiBjm',
#       'id': '09U6hmCerKcIJrixubiBjm',
#       'name': 'Pineapple StormTv',
#       'type': 'artist',
#       'uri': 'spotify:artist:09U6hmCerKcIJrixubiBjm'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/204IwDdaHE4ymGk9Kya2pY'},
#       'href': 'https://api.spotify.com/v1/artists/204IwDdaHE4ymGk9Kya2pY',
#       'id': '204IwDdaHE4ymGk9Kya2pY',
#       'name': 'Djonga',
#       'type': 'artist',
#       'uri': 'spotify:artist:204IwDdaHE4ymGk9Kya2pY'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/2ECTJpRqtJ5BbavpnhHT01'},
#       'href': 'https://api.spotify.com/v1/artists/2ECTJpRqtJ5BbavpnhHT01',
#       'id': '2ECTJpRqtJ5BbavpnhHT01',
#       'name': 'Tibery',
#       'type': 'artist',
#       'uri': 'spotify:artist:2ECTJpRqtJ5BbavpnhHT01'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/1CQPPiPRlXbiMvDBO67c6w'},
#       'href': 'https://api.spotify.com/v1/artists/1CQPPiPRlXbiMvDBO67c6w',
#       'id': '1CQPPiPRlXbiMvDBO67c6w',
#       'name': 'Felipe Artioli',
#       'type': 'artist',
#       'uri': 'spotify:artist:1CQPPiPRlXbiMvDBO67c6w'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 198181,
#     'explicit': False,
#     'external_ids': {'isrc': 'BX6Y62100003'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6jVKJqRxVVQh41CXmfnosE'},
#     'href': 'https://api.spotify.com/v1/tracks/6jVKJqRxVVQh41CXmfnosE',
#     'id': '6jVKJqRxVVQh41CXmfnosE',
#     'is_local': False,
#     'name': 'Neguin',
#     'popularity': 39,
#     'preview_url': 'https://p.scdn.co/mp3-preview/72ef1f83ca3d6372d35ddcd5aa49090672309680?cid=1ea081e3c4d04a178150f5287edcfb7f',
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:6jVKJqRxVVQh41CXmfnosE'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/76wdcgwzpdrlWDgnPyqhSP'},
#        'href': 'https://api.spotify.com/v1/artists/76wdcgwzpdrlWDgnPyqhSP',
#        'id': '76wdcgwzpdrlWDgnPyqhSP',
#        'name': 'Neguinha Braba',
#        'type': 'artist',
#        'uri': 'spotify:artist:76wdcgwzpdrlWDgnPyqhSP'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0n3uIu93AtrVR5c3mIvDAG'},
#      'href': 'https://api.spotify.com/v1/albums/0n3uIu93AtrVR5c3mIvDAG',
#      'id': '0n3uIu93AtrVR5c3mIvDAG',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27300cbb45ae3358d652c0c170a',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0200cbb45ae3358d652c0c170a',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485100cbb45ae3358d652c0c170a',
#        'width': 64}],
#      'name': 'Tem Mais Neguim',
#      'release_date': '2022-12-18',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:0n3uIu93AtrVR5c3mIvDAG'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/76wdcgwzpdrlWDgnPyqhSP'},
#       'href': 'https://api.spotify.com/v1/artists/76wdcgwzpdrlWDgnPyqhSP',
#       'id': '76wdcgwzpdrlWDgnPyqhSP',
#       'name': 'Neguinha Braba',
#       'type': 'artist',
#       'uri': 'spotify:artist:76wdcgwzpdrlWDgnPyqhSP'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 161026,
#     'explicit': True,
#     'external_ids': {'isrc': 'BX8KT2200013'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3V0ekgwkMkXbrIPc2XqYrI'},
#     'href': 'https://api.spotify.com/v1/tracks/3V0ekgwkMkXbrIPc2XqYrI',
#     'id': '3V0ekgwkMkXbrIPc2XqYrI',
#     'is_local': False,
#     'name': 'Tem Mais Neguim',
#     'popularity': 19,
#     'preview_url': 'https://p.scdn.co/mp3-preview/16194a1ffcde0c23ca874c56b915f9bbc0411b22?cid=1ea081e3c4d04a178150f5287edcfb7f',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:3V0ekgwkMkXbrIPc2XqYrI'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2OOD97aj04K9YoCAnHBHac'},
#        'href': 'https://api.spotify.com/v1/artists/2OOD97aj04K9YoCAnHBHac',
#        'id': '2OOD97aj04K9YoCAnHBHac',
#        'name': 'Cesar Neguinho',
#        'type': 'artist',
#        'uri': 'spotify:artist:2OOD97aj04K9YoCAnHBHac'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4JPjgWN3OPpMuYEIym25qY'},
#      'href': 'https://api.spotify.com/v1/albums/4JPjgWN3OPpMuYEIym25qY',
#      'id': '4JPjgWN3OPpMuYEIym25qY',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2739582939d2d212422c2334eee',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e029582939d2d212422c2334eee',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048519582939d2d212422c2334eee',
#        'width': 64}],
#      'name': 'Tris De Brumadinho Ao Ninho Do Urubu',
#      'release_date': '2019-02-01',
#      'release_date_precision': 'day',
#      'total_tracks': 3,
#      'type': 'album',
#      'uri': 'spotify:album:4JPjgWN3OPpMuYEIym25qY'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2OOD97aj04K9YoCAnHBHac'},
#       'href': 'https://api.spotify.com/v1/artists/2OOD97aj04K9YoCAnHBHac',
#       'id': '2OOD97aj04K9YoCAnHBHac',
#       'name': 'Cesar Neguinho',
#       'type': 'artist',
#       'uri': 'spotify:artist:2OOD97aj04K9YoCAnHBHac'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 401352,
#     'explicit': False,
#     'external_ids': {'isrc': 'AEA0D1933619'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4N8BIp9giB1ddkWi7t3l0R'},
#     'href': 'https://api.spotify.com/v1/tracks/4N8BIp9giB1ddkWi7t3l0R',
#     'id': '4N8BIp9giB1ddkWi7t3l0R',
#     'is_local': False,
#     'name': 'Da Tristeza a Alegria Paraty Canta chapecó',
#     'popularity': 0,
#     'preview_url': 'https://p.scdn.co/mp3-preview/7508dfa3ce5d8e8b83a65198e3f832f38234f64e?cid=1ea081e3c4d04a178150f5287edcfb7f',
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:4N8BIp9giB1ddkWi7t3l0R'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4MUtipvakXcTn6WTKm8pTU'},
#        'href': 'https://api.spotify.com/v1/artists/4MUtipvakXcTn6WTKm8pTU',
#        'id': '4MUtipvakXcTn6WTKm8pTU',
#        'name': 'Mc Nego Chave',
#        'type': 'artist',
#        'uri': 'spotify:artist:4MUtipvakXcTn6WTKm8pTU'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5rQRVhJGBTAIBDM6eIty25'},
#      'href': 'https://api.spotify.com/v1/albums/5rQRVhJGBTAIBDM6eIty25',
#      'id': '5rQRVhJGBTAIBDM6eIty25',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2739cefa4e8ab3f2bb27bf65246',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e029cefa4e8ab3f2bb27bf65246',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048519cefa4e8ab3f2bb27bf65246',
#        'width': 64}],
#      'name': 'Neguinho Rale',
#      'release_date': '2021-03-12',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:5rQRVhJGBTAIBDM6eIty25'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4MUtipvakXcTn6WTKm8pTU'},
#       'href': 'https://api.spotify.com/v1/artists/4MUtipvakXcTn6WTKm8pTU',
#       'id': '4MUtipvakXcTn6WTKm8pTU',
#       'name': 'Mc Nego Chave',
#       'type': 'artist',
#       'uri': 'spotify:artist:4MUtipvakXcTn6WTKm8pTU'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 170666,
#     'explicit': True,
#     'external_ids': {'isrc': 'QZGLM2169869'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/04iaBO5eJTBy4Q88lbxOot'},
#     'href': 'https://api.spotify.com/v1/tracks/04iaBO5eJTBy4Q88lbxOot',
#     'id': '04iaBO5eJTBy4Q88lbxOot',
#     'is_local': False,
#     'name': 'Neguinho Rale',
#     'popularity': 26,
#     'preview_url': 'https://p.scdn.co/mp3-preview/6970b19918e3ebaeee544fa522cc96938f3acd54?cid=1ea081e3c4d04a178150f5287edcfb7f',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:04iaBO5eJTBy4Q88lbxOot'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2OOD97aj04K9YoCAnHBHac'},
#        'href': 'https://api.spotify.com/v1/artists/2OOD97aj04K9YoCAnHBHac',
#        'id': '2OOD97aj04K9YoCAnHBHac',
#        'name': 'Cesar Neguinho',
#        'type': 'artist',
#        'uri': 'spotify:artist:2OOD97aj04K9YoCAnHBHac'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4JPjgWN3OPpMuYEIym25qY'},
#      'href': 'https://api.spotify.com/v1/albums/4JPjgWN3OPpMuYEIym25qY',
#      'id': '4JPjgWN3OPpMuYEIym25qY',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2739582939d2d212422c2334eee',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e029582939d2d212422c2334eee',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048519582939d2d212422c2334eee',
#        'width': 64}],
#      'name': 'Tris De Brumadinho Ao Ninho Do Urubu',
#      'release_date': '2019-02-01',
#      'release_date_precision': 'day',
#      'total_tracks': 3,
#      'type': 'album',
#      'uri': 'spotify:album:4JPjgWN3OPpMuYEIym25qY'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2OOD97aj04K9YoCAnHBHac'},
#       'href': 'https://api.spotify.com/v1/artists/2OOD97aj04K9YoCAnHBHac',
#       'id': '2OOD97aj04K9YoCAnHBHac',
#       'name': 'Cesar Neguinho',
#       'type': 'artist',
#       'uri': 'spotify:artist:2OOD97aj04K9YoCAnHBHac'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 229146,
#     'explicit': False,
#     'external_ids': {'isrc': 'AEA0D1933620'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3PrVvyngkGzbVjdZv2hjGY'},
#     'href': 'https://api.spotify.com/v1/tracks/3PrVvyngkGzbVjdZv2hjGY',
#     'id': '3PrVvyngkGzbVjdZv2hjGY',
#     'is_local': False,
#     'name': 'Simplismente Assim Fernanda Montenegro',
#     'popularity': 0,
#     'preview_url': 'https://p.scdn.co/mp3-preview/21a62dde6170f0ed74f22b53f574b3bee8bbc269?cid=1ea081e3c4d04a178150f5287edcfb7f',
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:3PrVvyngkGzbVjdZv2hjGY'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/05qCf6M7E7AxizHVmrcPqh'},
#        'href': 'https://api.spotify.com/v1/artists/05qCf6M7E7AxizHVmrcPqh',
#        'id': '05qCf6M7E7AxizHVmrcPqh',
#        'name': 'Kyan',
#        'type': 'artist',
#        'uri': 'spotify:artist:05qCf6M7E7AxizHVmrcPqh'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/13yQqjPy4Esq0Ru3R1fipU'},
#        'href': 'https://api.spotify.com/v1/artists/13yQqjPy4Esq0Ru3R1fipU',
#        'id': '13yQqjPy4Esq0Ru3R1fipU',
#        'name': 'Mu540',
#        'type': 'artist',
#        'uri': 'spotify:artist:13yQqjPy4Esq0Ru3R1fipU'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3gMr7Z43VxFxQuCkRiHoX8'},
#      'href': 'https://api.spotify.com/v1/albums/3gMr7Z43VxFxQuCkRiHoX8',
#      'id': '3gMr7Z43VxFxQuCkRiHoX8',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27327e62feab1d8a790142c98af',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0227e62feab1d8a790142c98af',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485127e62feab1d8a790142c98af',
#        'width': 64}],
#      'name': 'Dias Antes de Mandrake',
#      'release_date': '2022-10-11',
#      'release_date_precision': 'day',
#      'total_tracks': 11,
#      'type': 'album',
#      'uri': 'spotify:album:3gMr7Z43VxFxQuCkRiHoX8'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/05qCf6M7E7AxizHVmrcPqh'},
#       'href': 'https://api.spotify.com/v1/artists/05qCf6M7E7AxizHVmrcPqh',
#       'id': '05qCf6M7E7AxizHVmrcPqh',
#       'name': 'Kyan',
#       'type': 'artist',
#       'uri': 'spotify:artist:05qCf6M7E7AxizHVmrcPqh'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/13yQqjPy4Esq0Ru3R1fipU'},
#       'href': 'https://api.spotify.com/v1/artists/13yQqjPy4Esq0Ru3R1fipU',
#       'id': '13yQqjPy4Esq0Ru3R1fipU',
#       'name': 'Mu540',
#       'type': 'artist',
#       'uri': 'spotify:artist:13yQqjPy4Esq0Ru3R1fipU'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/5wEgjH2s4SAiffRmzkBqHB'},
#       'href': 'https://api.spotify.com/v1/artists/5wEgjH2s4SAiffRmzkBqHB',
#       'id': '5wEgjH2s4SAiffRmzkBqHB',
#       'name': 'Wall Hein',
#       'type': 'artist',
#       'uri': 'spotify:artist:5wEgjH2s4SAiffRmzkBqHB'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 148874,
#     'explicit': True,
#     'external_ids': {'isrc': 'BX46W2200010'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3CfLSQzysegtpk1JLXozcr'},
#     'href': 'https://api.spotify.com/v1/tracks/3CfLSQzysegtpk1JLXozcr',
#     'id': '3CfLSQzysegtpk1JLXozcr',
#     'is_local': False,
#     'name': 'Neguin 171',
#     'popularity': 52,
#     'preview_url': 'https://p.scdn.co/mp3-preview/bfdc0c0b419ac0d9ef691cda762aba2e255d9e14?cid=1ea081e3c4d04a178150f5287edcfb7f',
#     'track_number': 6,
#     'type': 'track',
#     'uri': 'spotify:track:3CfLSQzysegtpk1JLXozcr'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2OOD97aj04K9YoCAnHBHac'},
#        'href': 'https://api.spotify.com/v1/artists/2OOD97aj04K9YoCAnHBHac',
#        'id': '2OOD97aj04K9YoCAnHBHac',
#        'name': 'Cesar Neguinho',
#        'type': 'artist',
#        'uri': 'spotify:artist:2OOD97aj04K9YoCAnHBHac'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4JPjgWN3OPpMuYEIym25qY'},
#      'href': 'https://api.spotify.com/v1/albums/4JPjgWN3OPpMuYEIym25qY',
#      'id': '4JPjgWN3OPpMuYEIym25qY',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2739582939d2d212422c2334eee',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e029582939d2d212422c2334eee',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048519582939d2d212422c2334eee',
#        'width': 64}],
#      'name': 'Tris De Brumadinho Ao Ninho Do Urubu',
#      'release_date': '2019-02-01',
#      'release_date_precision': 'day',
#      'total_tracks': 3,
#      'type': 'album',
#      'uri': 'spotify:album:4JPjgWN3OPpMuYEIym25qY'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2OOD97aj04K9YoCAnHBHac'},
#       'href': 'https://api.spotify.com/v1/artists/2OOD97aj04K9YoCAnHBHac',
#       'id': '2OOD97aj04K9YoCAnHBHac',
#       'name': 'Cesar Neguinho',
#       'type': 'artist',
#       'uri': 'spotify:artist:2OOD97aj04K9YoCAnHBHac'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 255240,
#     'explicit': False,
#     'external_ids': {'isrc': 'AEA0D1933618'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1Stu3vTBYzQZ7ore1j8tOu'},
#     'href': 'https://api.spotify.com/v1/tracks/1Stu3vTBYzQZ7ore1j8tOu',
#     'id': '1Stu3vTBYzQZ7ore1j8tOu',
#     'is_local': False,
#     'name': 'Tris De Brumadinho Ao Ninho Do Urubu',
#     'popularity': 0,
#     'preview_url': 'https://p.scdn.co/mp3-preview/1dad318ead2c29605baa16dbd620995763e38f91?cid=1ea081e3c4d04a178150f5287edcfb7f',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:1Stu3vTBYzQZ7ore1j8tOu'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7e3FtKBIPLrIVm8g1FJMVg'},
#        'href': 'https://api.spotify.com/v1/artists/7e3FtKBIPLrIVm8g1FJMVg',
#        'id': '7e3FtKBIPLrIVm8g1FJMVg',
#        'name': 'Sango',
#        'type': 'artist',
#        'uri': 'spotify:artist:7e3FtKBIPLrIVm8g1FJMVg'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
# ...
#        'id': '27mVhYvJa7apj1zCoZ9TF2',
#        'name': 'MC Neguinho do Kaxeta',
#        'type': 'artist',
#        'uri': 'spotify:artist:27mVhYvJa7apj1zCoZ9TF2'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0JaSoVDrfBAzeGaMjzPatg'},
#      'href': 'https://api.spotify.com/v1/albums/0JaSoVDrfBAzeGaMjzPatg',
#      'id': '0JaSoVDrfBAzeGaMjzPatg',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2732c8674594ec61a0523325f7b',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e022c8674594ec61a0523325f7b',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048512c8674594ec61a0523325f7b',
#        'width': 64}],
#      'name': 'NK 20 Anos de Sucesso (Ao Vivo)',
#      'release_date': '2020-03-20',
#      'release_date_precision': 'day',
#      'total_tracks': 20,
#      'type': 'album',
#      'uri': 'spotify:album:0JaSoVDrfBAzeGaMjzPatg'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/27mVhYvJa7apj1zCoZ9TF2'},
#       'href': 'https://api.spotify.com/v1/artists/27mVhYvJa7apj1zCoZ9TF2',
#       'id': '27mVhYvJa7apj1zCoZ9TF2',
#       'name': 'MC Neguinho do Kaxeta',
#       'type': 'artist',
#       'uri': 'spotify:artist:27mVhYvJa7apj1zCoZ9TF2'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 212184,
#     'explicit': False,
#     'external_ids': {'isrc': 'BXG6R2000270'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4UobpfzxcDNBplXZ4rQwpm'},
#     'href': 'https://api.spotify.com/v1/tracks/4UobpfzxcDNBplXZ4rQwpm',
#     'id': '4UobpfzxcDNBplXZ4rQwpm',
#     'is_local': False,
#     'name': 'Diferenciado (Ao Vivo)',
#     'popularity': 46,
#     'preview_url': 'https://p.scdn.co/mp3-preview/124be9cf89a871317583a01a3ed75b1e2cbc92b5?cid=1ea081e3c4d04a178150f5287edcfb7f',
#     'track_number': 18,
#     'type': 'track',
#     'uri': 'spotify:track:4UobpfzxcDNBplXZ4rQwpm'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/27mVhYvJa7apj1zCoZ9TF2'},
#        'href': 'https://api.spotify.com/v1/artists/27mVhYvJa7apj1zCoZ9TF2',
#        'id': '27mVhYvJa7apj1zCoZ9TF2',
#        'name': 'MC Neguinho do Kaxeta',
#        'type': 'artist',
#        'uri': 'spotify:artist:27mVhYvJa7apj1zCoZ9TF2'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/26QTHpsRoZQ5xtBGfmFqcC'},
#      'href': 'https://api.spotify.com/v1/albums/26QTHpsRoZQ5xtBGfmFqcC',
#      'id': '26QTHpsRoZQ5xtBGfmFqcC',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273f508cbf1cd65161bff274943',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02f508cbf1cd65161bff274943',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851f508cbf1cd65161bff274943',
#        'width': 64}],
#      'name': 'Funk On The Beach',
#      'release_date': '2019-02-21',
#      'release_date_precision': 'day',
#      'total_tracks': 20,
#      'type': 'album',
#      'uri': 'spotify:album:26QTHpsRoZQ5xtBGfmFqcC'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/27mVhYvJa7apj1zCoZ9TF2'},
#       'href': 'https://api.spotify.com/v1/artists/27mVhYvJa7apj1zCoZ9TF2',
#       'id': '27mVhYvJa7apj1zCoZ9TF2',
#       'name': 'MC Neguinho do Kaxeta',
#       'type': 'artist',
#       'uri': 'spotify:artist:27mVhYvJa7apj1zCoZ9TF2'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 142623,
#     'explicit': False,
#     'external_ids': {'isrc': 'BXG6R1900093'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5QAS6GhRo2sEZchstjsFvo'},
#     'href': 'https://api.spotify.com/v1/tracks/5QAS6GhRo2sEZchstjsFvo',
#     'id': '5QAS6GhRo2sEZchstjsFvo',
#     'is_local': False,
#     'name': 'Mãezinha',
#     'popularity': 42,
#     'preview_url': 'https://p.scdn.co/mp3-preview/c32d6e2e9cc04fb3286c7cd677a1e2ad95cd7897?cid=1ea081e3c4d04a178150f5287edcfb7f',
#     'track_number': 10,
#     'type': 'track',
#     'uri': 'spotify:track:5QAS6GhRo2sEZchstjsFvo'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0Nks3cFWU2a7rooAlFQYgn'},
#        'href': 'https://api.spotify.com/v1/artists/0Nks3cFWU2a7rooAlFQYgn',
#        'id': '0Nks3cFWU2a7rooAlFQYgn',
#        'name': 'Cesária Evora',
#        'type': 'artist',
#        'uri': 'spotify:artist:0Nks3cFWU2a7rooAlFQYgn'}],
#      'available_markets': ['AG',
#       'AR',
#       'BB',
#       'BD',
#       'BN',
#       'BO',
#       'BS',
#       'BT',
#       'BZ',
#       'CL',
#       'CO',
#       'CR',
#       'CW',
#       'DM',
#       'DO',
#       'EC',
#       'GD',
#       'GT',
#       'GY',
#       'HN',
#       'HT',
#       'IN',
#       'JM',
#       'KH',
#       'KN',
#       'KR',
#       'LA',
#       'LC',
#       'LK',
#       'MV',
#       'MX',
#       'MY',
#       'NI',
#       'NP',
#       'PA',
#       'PE',
#       'PK',
#       'PY',
#       'SG',
#       'SR',
#       'SV',
#       'TH',
#       'TT',
#       'US',
#       'UY',
#       'VC',
#       'VE'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5G4y9tTcMnszKDHAsG6B7a'},
#      'href': 'https://api.spotify.com/v1/albums/5G4y9tTcMnszKDHAsG6B7a',
#      'id': '5G4y9tTcMnszKDHAsG6B7a',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27332e2b094bf6eb5e3fb0a0033',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0232e2b094bf6eb5e3fb0a0033',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485132e2b094bf6eb5e3fb0a0033',
#        'width': 64}],
#      'name': 'Sao Vicente',
#      'release_date': '2001-06-05',
#      'release_date_precision': 'day',
#      'total_tracks': 15,
#      'type': 'album',
#      'uri': 'spotify:album:5G4y9tTcMnszKDHAsG6B7a'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0Nks3cFWU2a7rooAlFQYgn'},
#       'href': 'https://api.spotify.com/v1/artists/0Nks3cFWU2a7rooAlFQYgn',
#       'id': '0Nks3cFWU2a7rooAlFQYgn',
#       'name': 'Cesária Evora',
#       'type': 'artist',
#       'uri': 'spotify:artist:0Nks3cFWU2a7rooAlFQYgn'}],
#     'available_markets': ['AG',
#      'AR',
#      'BB',
#      'BD',
#      'BN',
#      'BO',
#      'BS',
#      'BT',
#      'BZ',
#      'CL',
#      'CO',
#      'CR',
#      'CW',
#      'DM',
#      'DO',
#      'EC',
#      'GD',
#      'GT',
#      'GY',
#      'HN',
#      'HT',
#      'IN',
#      'JM',
#      'KH',
#      'KN',
#      'KR',
#      'LA',
#      'LC',
#      'LK',
#      'MV',
#      'MX',
#      'MY',
#      'NI',
#      'NP',
#      'PA',
#      'PE',
#      'PK',
#      'PY',
#      'SG',
#      'SR',
#      'SV',
#      'TH',
#      'TT',
#      'US',
#      'UY',
#      'VC',
#      'VE'],
#     'disc_number': 1,
#     'duration_ms': 226240,
#     'explicit': False,
#     'external_ids': {'isrc': 'FRX620145110'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2tpRqLwVh2D0uR5HjH5R2G'},
#     'href': 'https://api.spotify.com/v1/tracks/2tpRqLwVh2D0uR5HjH5R2G',
#     'id': '2tpRqLwVh2D0uR5HjH5R2G',
#     'is_local': False,
#     'name': 'Negue',
#     'popularity': 4,
#     'preview_url': 'https://p.scdn.co/mp3-preview/66bc93321c37a09b707ae5fe32865fb1c02e174c?cid=1ea081e3c4d04a178150f5287edcfb7f',
#     'track_number': 12,
#     'type': 'track',
#     'uri': 'spotify:track:2tpRqLwVh2D0uR5HjH5R2G'}],
#   'limit': 20,
#   'next': 'https://api.spotify.com/v1/search?query=Neguin+Cesar&type=track&offset=20&limit=20',
#   'offset': 0,
#   'previous': None,
#   'total': 613}}
